# %% [markdown]
# ## Solving the ODE system for 1mM

# %%
# Solving the ODE system for 1mM
from scipy.integrate import solve_ivp
import deriv_equations_Millard
from deriv_equations_Millard import deriv_Millard
import Millard_dict
from Millard_dict import DICT
import numpy as np
import matplotlib.pyplot as plt
from numpy import genfromtxt

# Initial conditions
GLC_1_0 = 12.6597333333333
ACE_env_1_0 = 0.958577777777778
X_1_0 = 0.06308
ACCOA_1_0 = 0.27745
ACP_1_0 = 0.06377
ACE_cell_1_0 = 1.0874

# Initial conditions vector
y_1_0 = [GLC_1_0, ACE_env_1_0, X_1_0, ACCOA_1_0, ACP_1_0, ACE_cell_1_0] 

res = solve_ivp(fun=deriv_Millard,
                t_span=(0,4.25),
                y0=y_1_0,
                method='LSODA',
                args=(DICT,),
                dense_output=True)

GLC, ACE_env, X, ACCOA, ACP, ACE_cell = res.y

# Load calibration data 
ode_data_1 = genfromtxt('data_1mM.csv', delimiter=',')

data_t = ode_data_1[1:, 0]  

# Plot everything
fig, axs = plt.subplots(2, 3, figsize=(15, 6))

axs[0,0].plot(res.t, GLC, label='GLC_gen', color='b')
axs[0,0].plot(data_t, ode_data_1[1:, 3], 'o', label='GLC_data', color='b')
axs[0,0].set_title('GLC 1mM')
axs[0,0].set_xlabel('t (h)')
axs[0,0].set_ylabel('GLC (mM)')
axs[0,0].legend()
axs[0,0].grid(True)

axs[0,1].plot(res.t, ACE_env, label='ACE_env_gen', color='g')
axs[0,1].plot(data_t, ode_data_1[1:, 1], 'o', label='ACE_env_data', color='g')
axs[0,1].set_title('ACE_env 1mM')
axs[0,1].set_xlabel('t (h)')
axs[0,1].set_ylabel('ACE_env (mM)')
axs[0,1].legend()
axs[0,1].grid(True)

axs[0,2].plot(res.t, X,label='X_gen', color='r')
axs[0,2].plot(data_t, ode_data_1[1:, 2], 'o',label='X_data', color='r')
axs[0,2].set_title('X 1mM')
axs[0,2].set_xlabel('t (h)')
axs[0,2].set_ylabel('X (g_DW/L)')
axs[0,2].legend()
axs[0,2].grid(True)

axs[1,0].plot(res.t, ACCOA, label='ACCOA_gen', color='m')
axs[1,0].set_title('ACCOA 1mM')
axs[1,0].set_xlabel('t (h)')
axs[1,0].set_ylabel('ACCOA')
axs[1,0].legend()
axs[1,0].grid(True)

axs[1,1].plot(res.t, ACP, label='ACP_gen', color='c')
axs[1,1].set_title('ACP 1mM')
axs[1,1].set_xlabel('t (h)')
axs[1,1].set_ylabel('ACP')
axs[1,1].legend()
axs[1,1].grid(True)

axs[1,2].plot(res.t, ACE_cell,label='ACE_cell_gen', color='y')
axs[1,2].set_title('ACE_cell 1mM')
axs[1,2].set_xlabel('t (h)')
axs[1,2].set_ylabel('ACE_cell')
axs[1,2].legend()
axs[1,2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Solving the ODE system for 10mM

# %%
# Solving the ODE system for 10mM

# Initial conditions
GLC_10_0 = 13.8064862685101
ACE_env_10_0 = 8.88456589469475
X_10_0 = 0.07904
ACCOA_10_0 = 9.77436650e-01
ACP_10_0 = 2.25033506e-01
ACE_cell_10_0 = 8.92425229

# Initial conditions vector
y_10_0 = [GLC_10_0, ACE_env_10_0, X_10_0, ACCOA_10_0, ACP_10_0, ACE_cell_10_0] 

res = solve_ivp(fun=deriv_Millard,
                t_span=(0.08,4.83),
                y0=y_10_0,
                method='LSODA',
                args=(DICT,),
                dense_output=True)

GLC, ACE_env, X, ACCOA, ACP, ACE_cell = res.y

# Load calibration data 
ode_data_10 = genfromtxt('data_10mM.csv', delimiter=',')

data_t = ode_data_10[1:, 0]  

# Plot everything
fig, axs = plt.subplots(2, 3, figsize=(15, 6))

axs[0,0].plot(res.t, GLC, label='GLC_gen', color='b')
axs[0,0].plot(data_t, ode_data_10[1:, 3], 'o', label='GLC_data', color='b')
axs[0,0].set_title('GLC 10mM')
axs[0,0].set_xlabel('t (h)')
axs[0,0].set_ylabel('GLC (mM)')
axs[0,0].legend()
axs[0,0].grid(True)

axs[0,1].plot(res.t, ACE_env, label='ACE_env_gen', color='g')
axs[0,1].plot(data_t, ode_data_10[1:, 1], 'o', label='ACE_env_data', color='g')
axs[0,1].set_title('ACE_env 10mM')
axs[0,1].set_xlabel('t (h)')
axs[0,1].set_ylabel('ACE_env (mM)')
axs[0,1].legend()
axs[0,1].grid(True)

axs[0,2].plot(res.t, X,label='X_gen', color='r')
axs[0,2].plot(data_t, ode_data_10[1:, 2], 'o',label='X_data', color='r')
axs[0,2].set_title('X 10mM')
axs[0,2].set_xlabel('t (h)')
axs[0,2].set_ylabel('X (g_DW/L)')
axs[0,2].legend()
axs[0,2].grid(True)

axs[1,0].plot(res.t, ACCOA, label='ACCOA_gen', color='m')
axs[1,0].set_title('ACCOA 10mM')
axs[1,0].set_xlabel('t (h)')
axs[1,0].set_ylabel('ACCOA')
axs[1,0].legend()
axs[1,0].grid(True)

axs[1,1].plot(res.t, ACP, label='ACP_gen', color='c')
axs[1,1].set_title('ACP 10mM')
axs[1,1].set_xlabel('t (h)')
axs[1,1].set_ylabel('ACP')
axs[1,1].legend()
axs[1,1].grid(True)

axs[1,2].plot(res.t, ACE_cell,label='ACE_cell_gen', color='y')
axs[1,2].set_title('ACE_cell 10mM')
axs[1,2].set_xlabel('t (h)')
axs[1,2].set_ylabel('ACE_cell')
axs[1,2].legend()
axs[1,2].grid(True)

plt.tight_layout()
plt.show()

print(ACE_cell)
# Out:
# [8.92425229 8.92425468 8.92425709 8.9242595  8.92426192 8.92426434
#  8.92426676 8.92426918 8.9242716  8.92427401 8.92427643 8.92427884
#  8.92428126 8.92428367 8.92428608 8.92428848 8.92429089 8.9242933
#  8.9242957  8.9242981  8.9243005  8.92430291 8.9243077  8.92431249
#  8.92435986 8.9244067  8.92482835 8.92520792 8.92701848 8.9278885
#  8.92855376 8.92871082 8.92886149 8.92897997 8.93016027 8.93135418
#  8.93911513 8.94745849 8.95642356 8.97575408 8.99793231 9.02337667
#  9.05254258 9.10890878 9.17885244 9.26525663 9.3713967  9.52226001
#  9.70878659 9.93039852 9.95432364 9.97513658 9.97804297 9.98061065
#  9.98273564 9.98472669 9.98313473 9.97937045 9.97828657 9.97720451
#  9.9760813  9.97336388 9.96996859 9.9647714  9.95754529 9.94759694
#  9.93065564 9.9041283  9.8768663  9.83938513 9.80466859 9.79925765
#  9.79387977 9.78842675 9.78285521 9.77156596 9.76021652 9.74896715
#  9.73030349 9.71773893 9.70599798 9.69749588 9.68957918 9.68222792
#  9.67455499 9.66762174 9.66136261 9.65568811 9.64971882 9.64434278
#  9.6394572  9.63497337 9.62866714 9.62289351 9.61749597 9.61237057
#  9.60743294 9.60198757 9.59664181 9.59135776 9.5861185  9.58090169
#  9.57349223 9.56609859 9.55871287 9.55133149 9.54395153 9.52973779
#  9.51552078 9.5012992  9.48707262 9.43115336 9.37515984 9.31909364
#  8.75141509 8.65988234]

# %% [markdown]
# ## Solving the ODE system for 30mM

# %%
# Solving the ODE system for 30mM

# Initial conditions
GLC_30_0 = 12.6936
ACE_env_30_0 = 29.9277777777777
X_30_0 = 0.0627
ACCOA_30_0 = 2.54059326
ACP_30_0 = 5.87314360e-01
ACE_cell_30_0 = 2.97040101e+01

# Initial conditions vector
y_30_0 = [GLC_30_0, ACE_env_30_0, X_30_0, ACCOA_30_0, ACP_30_0, ACE_cell_30_0] 

res = solve_ivp(fun=deriv_Millard,
                t_span=(0,5.72),
                y0=y_30_0,
                method='LSODA',
                args=(DICT,),
                dense_output=True)

GLC, ACE_env, X, ACCOA, ACP, ACE_cell = res.y

# Load calibration data 
ode_data_30 = genfromtxt('data_30mM.csv', delimiter=',')

data_t = ode_data_30[1:, 0]  

# Plot everything
fig, axs = plt.subplots(2, 3, figsize=(15, 6))

axs[0,0].plot(res.t, GLC, label='GLC_gen', color='b')
axs[0,0].plot(data_t, ode_data_30[1:, 3], 'o', label='GLC_data', color='b')
axs[0,0].set_title('GLC 30mM')
axs[0,0].set_xlabel('t (h)')
axs[0,0].set_ylabel('GLC (mM)')
axs[0,0].legend()
axs[0,0].grid(True)

axs[0,1].plot(res.t, ACE_env, label='ACE_env_gen', color='g')
axs[0,1].plot(data_t, ode_data_30[1:, 1], 'o', label='ACE_env_data', color='g')
axs[0,1].set_title('ACE_env 30mM')
axs[0,1].set_xlabel('t (h)')
axs[0,1].set_ylabel('ACE_env (mM)')
axs[0,1].legend()
axs[0,1].grid(True)

axs[0,2].plot(res.t, X,label='X_gen', color='r')
axs[0,2].plot(data_t, ode_data_30[1:, 2], 'o',label='X_data', color='r')
axs[0,2].set_title('X 30mM')
axs[0,2].set_xlabel('t (h)')
axs[0,2].set_ylabel('X (g_DW/L)')
axs[0,2].legend()
axs[0,2].grid(True)

axs[1,0].plot(res.t, ACCOA, label='ACCOA_gen', color='m')
axs[1,0].set_title('ACCOA 30mM')
axs[1,0].set_xlabel('t (h)')
axs[1,0].set_ylabel('ACCOA')
axs[1,0].legend()
axs[1,0].grid(True)

axs[1,1].plot(res.t, ACP, label='ACP_gen', color='c')
axs[1,1].set_title('ACP 30mM')
axs[1,1].set_xlabel('t (h)')
axs[1,1].set_ylabel('ACP')
axs[1,1].legend()
axs[1,1].grid(True)

axs[1,2].plot(res.t, ACE_cell,label='ACE_cell_gen', color='y')
axs[1,2].set_title('ACE_cell 30mM')
axs[1,2].set_xlabel('t (h)')
axs[1,2].set_ylabel('ACE_cell')
axs[1,2].legend()
axs[1,2].grid(True)

plt.tight_layout()
plt.show()

print(ACE_cell)
# Out:
# [29.7040101  29.70402226 29.70403436 29.7040585  29.70408249 29.70410638
#  29.70414492 29.70418335 29.7042217  29.70426001 29.70429828 29.70433652
#  29.70437474 29.70441294 29.70445112 29.70448928 29.70452742 29.70456554
#  29.70460365 29.70464174 29.70467981 29.70471787 29.70509746 29.70547533
#  29.70585149 29.70944121 29.71287486 29.74124059 29.75952867 29.77103784
#  29.78149636 29.78175355 29.78429487 29.78766549 29.79018414 29.79043761
#  29.79024485 29.78986177 29.78960091 29.78702266 29.78440299 29.76674197
#  29.74715876 29.72546037 29.68911744 29.64691464 29.59786252 29.54086485
#  29.43525288 29.30251271 29.13592576 28.92720052 28.63603724 28.26484311
#  27.79198131 27.347132  ]
